# %%
import importlib, trackAndTagComplete, arcLength, drawEllipses, filterData, bolaLineTension, isolateDomains, fitEllipse



importlib.reload(trackAndTagComplete)
importlib.reload(arcLength)
importlib.reload(drawEllipses)
importlib.reload(fitEllipse)
importlib.reload(bolaLineTension)
importlib.reload(filterData)
importlib.reload(isolateDomains)
# Out:
# <module 'isolateDomains' from '/Users/myleskoppelman/Documents/University Of Minnesota/Augsburg Internship 2025/python/BolaLineTension/isolateDomains.py'>

# %%
trackAndTagComplete.main()
# Out:
# Running trackAndTagComplete.py. Please respond to all GUI prompts...
# 2025-08-08 10:21:24.912 python[69671:11075182] The class 'NSOpenPanel' overrides the method identifier.  This method is implemented by class 'NSWindow'
# 2025-08-08 10:21:56.748 python[69671:11075182] The class 'NSSavePanel' overrides the method identifier.  This method is implemented by class 'NSWindow'
# Options Complete...
# Thresholding and Analyzing Particles: 100%|██████████| 19/19 [00:00<00:00, 747.71it/s]
# Threshold and Analysis Complete...
# Successfully removed Particles smaller than min_area or larger than max_eccentricity...
# Tracking Particles: 100%|██████████| 62/62 [00:00<00:00, 11151.72it/s, 100 %]
# Particles Successfuly Tracked...
# Calculating Displacements: 100%|██████████| 9/9 [00:00<00:00, 97794.65it/s]
# Calculating Averages: 0it [00:00, ?it/s]
# Tracking Particles: 100%|██████████| 62/62 [00:00<00:00, 10756.41it/s, 100 %]
# Particles Successfuly Tracked...
# ...

# %%
filterData.main()
# Out:
# Removed Particle 3
# Removed Particle 4
# Removed Particle 5
# Removed Particle 6
# Filtered Data saved to /Users/myleskoppelman/Documents/University Of Minnesota/Augsburg Internship 2025/Substack (166-184)_BIN_FLTR.tif

# %%
isolateDomains.main()
# Out:
# Saved Domains to: /Users/myleskoppelman/Documents/University Of Minnesota/Augsburg Internship 2025/Substack (166-184)_BIN_ISO.tif

# %%
filterData.main()
# Out:
# Filtered Data saved to /Users/myleskoppelman/Documents/University Of Minnesota/Augsburg Internship 2025/Substack (166-184)_BIN_ISO_FLTR.tif

# %%
bolaLineTension.main()
# Out:
# Fitting Arc Length:  89%|████████▉ | 17/19 [00:00<00:00, 39.15it/s]/Users/myleskoppelman/Documents/University Of Minnesota/Augsburg Internship 2025/python/BolaLineTension/arcLength.py:134: RankWarning: Polyfit may be poorly conditioned
#   coeffs = np.polyfit(x_data, y_data, 2)
# /Users/myleskoppelman/Documents/University Of Minnesota/Augsburg Internship 2025/python/BolaLineTension/arcLength.py:134: RankWarning: Polyfit may be poorly conditioned
#   coeffs = np.polyfit(x_data, y_data, 2)
# Fitting Arc Length: 100%|██████████| 19/19 [00:00<00:00, 34.93it/s]
# Saved ellipses and polynomials to: /Users/myleskoppelman/Documents/University Of Minnesota/Augsburg Internship 2025/Substack (166-184)_BIN_ISO_FLTR_LT.tif
#
#
# Weighted Average Line Tension: -1.5769182255902977e-13 Newtons
# Median Line Tension: -1.5365055123444016e-13 Newtons
# All data saved to: /Users/myleskoppelman/Documents/University Of Minnesota/Augsburg Internship 2025/Substack (166-184)_BIN_ISO_FLTR_LT_DATA.xlsx
# ...
